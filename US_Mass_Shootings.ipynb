# %%
#importing libraries
import numpy as np
import pandas as pd

# %%
#loading dataset
df = pd.read_csv("Mass Shootings Dataset.csv",encoding = "Latin-1",index_col=0)
df.head()
# Out:
#                                   Title                Location        Date  \
# S#
# 1            Texas church mass shooting  Sutherland Springs, TX   11/5/2017
# 2   Walmart shooting in suburban Denver            Thornton, CO   11/1/2017
# 3       Edgewood businees park shooting            Edgewood, MD  10/18/2017
# 4         Las Vegas Strip mass shooting           Las Vegas, NV   10/1/2017
# 5            San Francisco UPS shooting       San Francisco, CA   6/14/2017
#
#                                   Incident Area Open/Close Location  \
# S#
# 1                                        Church               Close
# 2                                      Wal-Mart                Open
# 3                              Remodeling Store               Close
# 4   Las Vegas Strip Concert outside Mandala Bay                Open
# 5                                  UPS facility               Close
#
#        Target    Cause                                            Summary  \
# S#
# ...

# %%
df.shape
# Out:
# (323, 20)

# %%
#stripping of white spaces from state's column
df['State']=df['Location'].str.split(",").str[1]

# %%
# rearranging the columns and adding new column
cols = list(df.columns)
cols
# Out:
# ['Title',
#  'Location',
#  'Date',
#  'Incident Area',
#  'Open/Close Location',
#  'Target',
#  'Cause',
#  'Summary',
#  'Fatalities',
#  'Injured',
#  'Total victims',
#  'Policeman Killed',
#  'Age',
#  'Employeed (Y/N)',
#  'Employed at',
#  'Mental Health Issues',
#  'Race',
#  'Gender',
#  'Latitude',
#  'Longitude',
#  'State']

# %%
list1 = []
list1.extend(cols[:2])
list1.append(cols[-1])
list1.extend(cols[2:20])

# %%
list1
# Out:
# ['Title',
#  'Location',
#  'State',
#  'Date',
#  'Incident Area',
#  'Open/Close Location',
#  'Target',
#  'Cause',
#  'Summary',
#  'Fatalities',
#  'Injured',
#  'Total victims',
#  'Policeman Killed',
#  'Age',
#  'Employeed (Y/N)',
#  'Employed at',
#  'Mental Health Issues',
#  'Race',
#  'Gender',
#  'Latitude',
#  'Longitude']

# %%
df = df[list1]

# %%
df.head()
# Out:
#                                   Title                Location State  \
# S#
# 1            Texas church mass shooting  Sutherland Springs, TX    TX
# 2   Walmart shooting in suburban Denver            Thornton, CO    CO
# 3       Edgewood businees park shooting            Edgewood, MD    MD
# 4         Las Vegas Strip mass shooting           Las Vegas, NV    NV
# 5            San Francisco UPS shooting       San Francisco, CA    CA
#
#           Date                                Incident Area  \
# S#
# 1    11/5/2017                                       Church
# 2    11/1/2017                                     Wal-Mart
# 3   10/18/2017                             Remodeling Store
# 4    10/1/2017  Las Vegas Strip Concert outside Mandala Bay
# 5    6/14/2017                                 UPS facility
#
#    Open/Close Location     Target    Cause  \
# S#
# 1                Close     random  unknown
# 2                 Open     random  unknown
# ...

# %%
df['State'].value_counts()
# Out:
#  California        28
#  Florida           20
#  Texas             16
#  Washington        14
#  Georgia           13
#  Arizona           11
#  North Carolina    11
#  Ohio              10
#  New York          10
#  Wisconsin          9
#  Illinois           9
#  Alabama            9
#  Pennsylvania       6
#  Michigan           6
#  Colorado           6
#  Oklahoma           5
#  Nevada             5
#  Kentucky           5
#  South Carolina     5
#  Tennessee          5
#  Virginia           5
#  Louisiana          4
#  Minnesota          4
#  Oregon             4
#  Kansas             4
#  Mississippi        4
#  Massachusetts      4
#  Missouri           3
#  New Jersey         3
#  Connecticut        3
#  Nebraska           3
#  Montana            2
#  Arkansas           2
#  Utah               2
#  New Mexico         2
#  CA                 2
#  Souderton          1
#  WA                 1
#  South Dakota       1
#  NV                 1
#  TX                 1
# ...

# %%
df['State'] = df['State'].str.strip()

# %%
df['State'].value_counts()
# Out:
# California        28
# Florida           20
# Texas             17
# Washington        14
# Georgia           13
# Arizona           11
# North Carolina    11
# Ohio              10
# New York          10
# Alabama            9
# Illinois           9
# Wisconsin          9
# Pennsylvania       6
# Colorado           6
# Virginia           6
# Michigan           6
# Tennessee          5
# Oklahoma           5
# South Carolina     5
# Nevada             5
# Kentucky           5
# Massachusetts      4
# Kansas             4
# Mississippi        4
# Oregon             4
# Louisiana          4
# Minnesota          4
# Connecticut        3
# Missouri           3
# New Jersey         3
# Nebraska           3
# Arkansas           2
# Utah               2
# Montana            2
# New Mexico         2
# CA                 2
# Idaho              1
# CO                 1
# NV                 1
# Hawaii             1
# Indiana            1
# Iowa               1
# Wyoming            1
# ...

# %%
df['State'].value_counts().sort_index()
# Out:
# Alabama            9
# Alaska             1
# Albuquerque        1
# Arizona           11
# Arkansas           2
# CA                 2
# CO                 1
# California        28
# Colorado           6
# Connecticut        3
# Florida           20
# Georgia           13
# Hawaii             1
# Idaho              1
# Illinois           9
# Indiana            1
# Iowa               1
# Kansas             4
# Kentucky           5
# LA                 1
# Lancaster          1
# Louisiana          4
# MD                 1
# Maine              1
# Massachusetts      4
# Michigan           6
# Minnesota          4
# Mississippi        4
# Missouri           3
# Montana            2
# NV                 1
# Nebraska           3
# Nevada             5
# New Jersey         3
# New Mexico         2
# New York          10
# North Carolina    11
# Ohio              10
# Oklahoma           5
# Oregon             4
# PA                 1
# Pennsylvania       6
# San Diego          1
# ...

# %%
#replacing with the correct values
df['State']=df['State'].replace({"CA":'California',"CO":'Colorado',"LA":'Louisiana','MD':'Maryland','NV':'Nevada','PA':'Pennsylvania','TX':'Texas','WA':'Washington'})

# %%
df['State'].value_counts().sort_index()
# Out:
# Alabama            9
# Alaska             1
# Albuquerque        1
# Arizona           11
# Arkansas           2
# California        30
# Colorado           7
# Connecticut        3
# Florida           20
# Georgia           13
# Hawaii             1
# Idaho              1
# Illinois           9
# Indiana            1
# Iowa               1
# Kansas             4
# Kentucky           5
# Lancaster          1
# Louisiana          5
# Maine              1
# Maryland           1
# Massachusetts      4
# Michigan           6
# Minnesota          4
# Mississippi        4
# Missouri           3
# Montana            2
# Nebraska           3
# Nevada             6
# New Jersey         3
# New Mexico         2
# New York          10
# North Carolina    11
# Ohio              10
# Oklahoma           5
# Oregon             4
# Pennsylvania       7
# San Diego          1
# Souderton          1
# South Carolina     5
# South Dakota       1
# Tennessee          5
# Texas             18
# ...

# %%
df['State'].replace({'Albuquerque':'New Mexico','Lancaster':np.nan,'San Diego':'California','Souderton':'Pennsylvania'},inplace=True)

# %%
df[df['State'].isnull()==True]
# Out:
#                                            Title  \
# S#
# 16                Forestville, Maryland Drive-by
# 17                            Halifax County, VA
# 18              Tire-Slashing revenge escalation
# 19                    Chicago Rap video Shootout
# 20                   Texas family murder-suicide
# 21               Alabama highway random shooting
# 22                      Long Beach Street murder
# 23          Albuquerque, NM House party shooting
# 24              Memphis, TN gas station shooting
# 25           Chicago Birthday Party Bus Shooting
# 26    Albuquerque, NM Family restaurant shooting
# 30           Greenhill, AL Family murder-suicide
# 35                    Atlanta Nightclub shooting
# 36   Florida Family celebration ends in shooting
# 37              Elberton, Georgia murder-suicide
# 38                 Trenton, NJ sidewalk shooting
# 39                              Detroit Drive-by
# 41              Wilkinsburg BBQ cookout shootout
# ...

# %%
df.loc[16,'Location']='Forestville,Maryland'
df.loc[17,'Location']='Halifax County, VA'
df.loc[23,'Location'] = 'Albuquerque, NM'
df.loc[24,'Location'] = 'Memphis,TN'
df.loc[26,'Location'] = 'Albuquerque, NM'
df.loc[30,'Location']='Greenhill, AL'
df.loc[37,'Location']='Elberton,Georgia'
df.loc[38,'Location']='Trenton,NJ'
df.loc[43,'Location']='Lafayette,LA'
df.loc[46,'Location']='Roswell, GA'
df.loc[54,'Location']='Belfair, WA'
df.loc[62,'Location']='Vallejo, CA'
df.loc[66,'Location'] ='Tampa, FL'
df.loc[67,'Location']='Los Angeles, CA'
df.loc[70,'Location']='Glendale, AZ'
df.loc[71,'Location']='Caroline County, VA'
df.loc[73,'Location']='Perris, CA'
df.loc[76,'Location']='Gloucester County, VA'
df.loc[77,'Location']='Wilmington, DE'
df.loc[78,'Location']='Memphis, Tennessee'
df.loc[79,'Location']='Lakeland, Florida'

# %%
df['State']=df['Location'].str.split(",").str[1]

# %%
df['State'].replace({'VA':'Virginia','NM':'New Mexico','TN':'Tennessee',
                     'AL':'Alabama','NJ':'New Jersey','LA':'Louisiana','GA':'Georgia',
                    'WA':'Washington','CA':'California','FL':'Florida','AZ':'Arizona','DE':'Delaware'},inplace=True)

# %%
df[df['State'].isnull()==True]
# Out:
#                                            Title         Location State  \
# S#
# 18              Tire-Slashing revenge escalation              NaN   NaN
# 19                    Chicago Rap video Shootout              NaN   NaN
# 20                   Texas family murder-suicide              NaN   NaN
# 21               Alabama highway random shooting              NaN   NaN
# 22                      Long Beach Street murder              NaN   NaN
# 25           Chicago Birthday Party Bus Shooting              NaN   NaN
# 35                    Atlanta Nightclub shooting              NaN   NaN
# 36   Florida Family celebration ends in shooting              NaN   NaN
# 39                              Detroit Drive-by              NaN   NaN
# 41              Wilkinsburg BBQ cookout shootout              NaN   NaN
# 44                     Kansas City Home Invasion              NaN   NaN
# 47                    Wichita Nightclub shooting              NaN   NaN
# ...

# %%
#filling missing data with appropriate values after getting information from reseasrching articles in google
df.loc[25,'Summary']
# Out:
# 'Birthday party bus was dropping off party goers in South Shore Chicago when someone on the street started shooting at them. The bus driver drove off quickly protecting the targets. Unknown motivation. No suspects. '

# %% [markdown]
# https://abc7chicago.com/party-bus-shooting-70th-paxton-south-shore/1280390/

# %%
df.loc[25,'Location']='Chicago,Illinois'
df.loc[25,'State']='Illinois'

# %%
df.loc[39,'Summary']
# Out:
# 'Four men were sitting on a porch when a black SUV with three passengers drove by and opened fire in broad daylight. Two of the men died and two were injured. The SUV got away and there are no suspects'

# %% [markdown]
# https://www.detroitnews.com/story/news/local/detroit-city/2016/03/11/dead-wounded-drive-detroit/81665078/

# %%
df.loc[39,'Location'] = 'Detroit,Michigan'
df.loc[39,'State']='Michigan'
df.loc[39,'Incident Area'] ='Home'

# %%
df.loc[41,'Summary']
# Out:
# 'A family was having a cookout in the backyard of a house when two gunmen came and started shooting. There is one suspected target, but 5 people were killed, including one pregnant woman. The two gunmen fled the scene and have not been identified.'

# %% [markdown]
# https://edition.cnn.com/2016/03/10/us/pennsylvania-shooting/index.html

# %%
df.loc[41,'Location'] = 'Wilkinsburg,Pennsylvania'
df.loc[41,'State'] = 'Pennsylvania'

# %%
df.loc[49,'Summary']
# Out:
# 'Shooter fired upon group of people in a restaurant parking lot'

# %% [markdown]
# https://www.pe.com/2016/09/09/fugitive-arrested-in-perris-restaurant-shooting-that-killed-1-injured-4-update/

# %%
df.loc[49,'Location'] = "Perris,California"
df.loc[49,'State']='California'

# %%
df.loc[56,'Summary']
# Out:
# 'Car was fired upon from a stolen Mercedes on the interstate in Hazelwood, MO. One woman died. 3 Injured.'

# %% [markdown]
# https://www.kmov.com/news/centralia-woman-killed-3-others-injured-in-hazelwood-interstate-shooting/article_27e099fa-483e-5c2c-bebb-7b465244e354.html

# %%
df.loc[56,'Location'] = 'North Lindbergh Boulevard,Hazelwood,Missouri'
df.loc[56,'State'] = 'Missouri'

# %%
df.loc[61,'Summary']
# Out:
# 'An Uber driver fired upon people in three locations over the course of about 6 hours.'

# %% [markdown]
# https://edition.cnn.com/2016/02/21/us/michigan-kalamazoo-county-shooting-spree/index.html

# %%
df.loc[61,'Location']='Kalamazoo,Michigan'
df.loc[61,'State'] = 'Michigan'

# %%
df.loc[75,'Summary']
# Out:
# 'Group of people was standing outside of a Liquor store on Avalon boulevard in South Los Angeles. A car drove by and fired an AK-47, killing 1 and wounding 3.'

# %% [markdown]
# https://ktla.com/news/local-news/3-shot-in-south-l-a-s-vermont-knolls-neighborhood-lapd/

# %%
df.loc[75,'Location']='Los Angeles,California'
df.loc[75,'State']='California'

# %%
df.loc[164,'Summary']
# Out:
# 'On September 16, 2013, a 34-yearl old contractor for the Navy Yard in Washington D.C, entered the building shooting randomly, killing twelve people and injuring three surviving victims before he was shot and killed by law enforcement officers.  Five other people were injured during the incident while trying to escape.'

# %% [markdown]
# https://www.nytimes.com/2013/09/17/us/shooting-reported-at-washington-navy-yard.html

# %%
df.loc[164,'Location']='Washington Navy Yard,Washington D.C.'
df.loc[164,'State']='Washington D.C.'

# %%
df[df['State'].isnull()==True]
# Out:
#                                           Title Location State       Date  \
# S#
# 18             Tire-Slashing revenge escalation      NaN   NaN  4/21/2016
# 19                   Chicago Rap video Shootout      NaN   NaN  4/19/2016
# 20                  Texas family murder-suicide      NaN   NaN  4/19/2016
# 21              Alabama highway random shooting      NaN   NaN  4/19/2016
# 22                     Long Beach Street murder      NaN   NaN  4/18/2016
# 35                   Atlanta Nightclub shooting      NaN   NaN  3/15/2016
# 36  Florida Family celebration ends in shooting      NaN   NaN  3/13/2016
# 44                    Kansas City Home Invasion      NaN   NaN   3/7/2016
# 47                   Wichita Nightclub shooting      NaN   NaN   3/5/2016
# 48                  Detroit Strip Club Shootout      NaN   NaN  2/28/2016
# 57                             Houston Drive-by      NaN   NaN  2/21/2016
# 60                  Florida Hookah Bar Shooting      NaN   NaN  2/20/2016
# ...

# %%
#replacing values from title and location column for location and state columns.
df.loc[19,'Location']='Chicago,Illinois'
df.loc[19,'State']='Illinois'
df.loc[20,'State']='Texas'
df.loc[21,'State']='Alabama'
df.loc[22,'Location']='Long Beach,California'
df.loc[22,'State']='California'
df.loc[35,'Location']='Atlanta,Georgia'
df.loc[35,'State']='Georgia'
df.loc[36,'State']='Florida'
df.loc[44,'State']='Kansas'
df.loc[47,'Location']='Wichita,Kansas'
df.loc[47,'State']='Kansas'
df.loc[48,'Location']='Detroit,Michigan'
df.loc[48,'State']='Michigan'
df.loc[57,'Location']='Houston,Texas'
df.loc[57,'State']='Texas'
df.loc[57,'State']='Florida'
df.loc[63,'State']='Michigan'
df.loc[68,'State']='Texas'
df.loc[69,'Location']='New Orleans,Louisiana'
df.loc[69,'State']='Louisiana'
df.loc[74,'State']='Florida'

# %%
df[df['State'].isnull()==True]
# Out:
#                                   Title Location State       Date  \
# S#
# 18     Tire-Slashing revenge escalation      NaN   NaN  4/21/2016
# 60          Florida Hookah Bar Shooting      NaN   NaN  2/20/2016
# 65  Nightclub fight turns into shootout      NaN   NaN   2/7/2016
#
#          Incident Area Open/Close Location  Target        Cause  \
# S#
# 18         block party                Open  random  frustration
# 60  hookah bar parking                Open  random        anger
# 65           nightclub               Close  random        anger
#
#                                               Summary  Fatalities  ...  \
# S#                                                                 ...
# 18  Shooter was angry over fact that rival familie...           0  ...
# 60  Argument led to gun shots in the parking lot o...           1  ...
# 65  Two groups of people fired at each other after...           1  ...
#
# ...

# %%
df.loc[60,'Summary']
# Out:
# 'Argument led to gun shots in the parking lot outside of a hookah bar in Tampa, Florida'

# %%
df.loc[60,'Location']='Tampa,Florida'
df.loc[60,'State']='Florida'

# %%
df.loc[65,'Summary']
# Out:
# 'Two groups of people fired at each other after a fight broke out outside of the Mexican Village Nightclub in Rochester, NY'

# %%
df.loc[65,'Location']='Rochester,New York'
df.loc[65,'State']='New York'

# %%
df[df['State'].isnull()==True]
# Out:
#                                Title Location State       Date Incident Area  \
# S#
# 18  Tire-Slashing revenge escalation      NaN   NaN  4/21/2016   block party
#
#    Open/Close Location  Target        Cause  \
# S#
# 18                Open  random  frustration
#
#                                               Summary  Fatalities  ...  \
# S#                                                                 ...
# 18  Shooter was angry over fact that rival familie...           0  ...
#
#     Total victims  Policeman Killed  Age Employeed (Y/N)  Employed at  \
# S#
# 18              4               0.0  NaN             NaN          NaN
#
#    Mental Health Issues                                Race Gender   Latitude  \
# S#
# 18              Unknown  Black American or African American   Male  39.290385
#
#     Longitude
# S#
# 18 -76.612189
#
# [1 rows x 21 columns]

# %%
df[df['Incident Area'].isnull()==True]
# Out:
#                                            Title                   Location  \
# S#
# 12                   Baton Rouge police shooting            Baton Rouge, LA
# 15                         Ferguson, MO Drive by         Ferguson, Missouri
# 28                     Louisburg, North Carolina  Louisburg, North Carolina
# 31          Sherman, Texas Family Murder-Suicide            Sherman, Texas
# 36   Florida Family celebration ends in shooting                        NaN
# ..                                           ...                        ...
# 309                49th Street Elementary School    Los Angeles, California
# 312                        Welding shop in Miami             Miami, Florida
# 315           Grover Cleveland Elementary School      San Diego, California
# 318                            Olean High School            Olean, New York
# 320                 New Orleans Police Shootings     New Orleans, Louisiana
#
# ...

# %%
df.isnull().sum()
# Out:
# Title                     0
# Location                  8
# State                     1
# Date                      0
# Incident Area            61
# Open/Close Location      28
# Target                    5
# Cause                    77
# Summary                   0
# Fatalities                0
# Injured                   0
# Total victims             0
# Policeman Killed          6
# Age                     144
# Employeed (Y/N)         256
# Employed at             282
# Mental Health Issues      0
# Race                      2
# Gender                    0
# Latitude                 20
# Longitude                20
# dtype: int64

# %%
df[df['Incident Area'].isnull()==True]
# Out:
#                                            Title                   Location  \
# S#
# 12                   Baton Rouge police shooting            Baton Rouge, LA
# 15                         Ferguson, MO Drive by         Ferguson, Missouri
# 28                     Louisburg, North Carolina  Louisburg, North Carolina
# 31          Sherman, Texas Family Murder-Suicide            Sherman, Texas
# 36   Florida Family celebration ends in shooting                        NaN
# ..                                           ...                        ...
# 309                49th Street Elementary School    Los Angeles, California
# 312                        Welding shop in Miami             Miami, Florida
# 315           Grover Cleveland Elementary School      San Diego, California
# 318                            Olean High School            Olean, New York
# 320                 New Orleans Police Shootings     New Orleans, Louisiana
#
# ...

# %%
df.loc[13,'Incident Area']='outside plaza'
df.loc[16,'Incident Area']='Drive by'
df.loc[37,'Incident Area']='Home'
df.loc[40,'Incident Area']='Drive by'
df.loc[47,'Incident Area']='Hookah bar'
df.loc[54,'Incident Area']='workplace'
df.loc[63,'Incident Area']='car shooting'
df.loc[67,'Incident Area']='Street shooting'
df.loc[68,'Incident Area']='Home'
df.loc[71,'Incident Area']='Home'
df.loc[74,'Incident Area']='Home'
df.loc[78,'Incident Area']='Roadside'
df.loc[88,'Incident Area']='Home'
df.loc[94,'Incident Area']='Home'
df.loc[98,'Incident Area']='Home'
df.loc[109,'Incident Area']='Bridge'
df.loc[110,'Incident Area']='Deer Lodge'
df.loc[114,'Incident Area']='Home'
df.loc[120,'Incident Area']='Home'
df.loc[126,'Incident Area']='Home'
df.loc[127,'Incident Area']='Home'
df.loc[140,'Incident Area']='Home'
df.loc[146,'Incident Area']='party bus'
df.loc[161,'Incident Area']='Bar'
df.loc[164,'Incident Area']='Shipyard'
df.loc[165,'Incident Area']='Home'
df.loc[169,'Incident Area']='College'
df.loc[170,'Incident Area']='School'
df.loc[185,'Incident Area']='Cafe'
df.loc[186,'Incident Area']='Cafe'

# %%
df.loc[194,'Incident Area']='Home'
df.loc[207,'Incident Area']='Home'
df.loc[226,'Incident Area']='University'
df.loc[234,'Incident Area']='Nightclub'
df.loc[244,'Incident Area']='Inn'
df.loc[297,'Incident Area']='Auto Parts + School'
df.loc[301,'Incident Area']='Neighborhood + Shopping Center'
df.loc[309,'Incident Area']='School'
df.loc[312,'Incident Area']='Welding Shop'
df.loc[315,'Incident Area']='School'
df.loc[318,'Incident Area']='School'
df.loc[320,'Incident Area']='Police Station + Hotel'

# %%
df.loc[15,'Incident Area']='Drive by'
df.loc[28,'Incident Area']='Home'
df.loc[31,'Incident Area']='Home'
df.loc[53,'Incident Area'] = 'workplace'
df.loc[57,'Incident Area']='Drive by'
df.loc[293,'Incident Area']='Home + workplace'

# %%
df.loc[289,'Incident Area']='Home + Workplace'
df.loc[177,'Incident Area']='Home + School'
df.loc[174,'Incident Area']='Parking Garage + Cabin'
df.loc[172,'Incident Area']='Car Service + Barbershop'

# %%
df[df['Incident Area'].isnull()==True]
# Out:
#                                            Title                     Location  \
# S#
# 12                   Baton Rouge police shooting              Baton Rouge, LA
# 36   Florida Family celebration ends in shooting                          NaN
# 46                   Roswell, GA Hookah shootout                  Roswell, GA
# 61           Kalamazoo Uber Driver Spree Killing           Kalamazoo,Michigan
# 62                      Vallejo, CA car shooting                  Vallejo, CA
# 80                               Omaha, Nebraska              Omaha, Nebraska
# 135                                      Killeen               Killeen, Texas
# 155                       Isla Vista mass murder    Santa Barbara, California
# 160                   Cedarville Rancheria Tribe          Alturas, California
# 173   Ladera Ranch, Santa Ana, Tustin and Orange     Ladera Ranch, California
# 197                              Tucson shooting              Tucson, Arizona
# ...

# %%
df.isnull().sum()
# Out:
# Title                     0
# Location                  8
# State                     1
# Date                      0
# Incident Area            16
# Open/Close Location      28
# Target                    5
# Cause                    77
# Summary                   0
# Fatalities                0
# Injured                   0
# Total victims             0
# Policeman Killed          6
# Age                     144
# Employeed (Y/N)         256
# Employed at             282
# Mental Health Issues      0
# Race                      2
# Gender                    0
# Latitude                 20
# Longitude                20
# dtype: int64

# %%
#droppinh all above 40%
df.drop(['Title','Open/Close Location','Cause','Age','Employeed (Y/N)','Employed at','Latitude','Longitude'],axis=1,inplace=True)

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# Location                2.476780
# State                   0.309598
# Date                    0.000000
# Incident Area           4.953560
# Target                  1.547988
# Summary                 0.000000
# Fatalities              0.000000
# Injured                 0.000000
# Total victims           0.000000
# Policeman Killed        1.857585
# Mental Health Issues    0.000000
# Race                    0.619195
# Gender                  0.000000
# dtype: float64

# %%
df.Gender.value_counts()
# Out:
# Male           272
# Unknown         21
# M               20
# Female           5
# Male/Female      4
# M/F              1
# Name: Gender, dtype: int64

# %%
df['Gender'].replace({'M':'Male','M/F':'Male/Female'},inplace=True)

# %%
df.Gender.value_counts()
# Out:
# Male           292
# Unknown         21
# Male/Female      5
# Female           5
# Name: Gender, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 38

# %%
df['State'] = df['State'].str.strip()

# %%
df['State'].unique()
# Out:
# array(['TX', 'CO', 'MD', 'NV', 'CA', 'PA', 'Florida', 'Ohio',
#        'California', 'WA', 'LA', 'Texas', 'Missouri', 'Maryland', 'VA',
#        nan, 'Illinois', 'Alabama', 'NM', 'Tennessee', 'Virginia',
#        'North Carolina', 'AL', 'Kentucky', 'Georgia', 'New Jersey',
#        'Michigan', 'Pennsylvania', 'Kansas', 'Louisiana', 'Massachusetts',
#        'GA', 'Washington', 'Arizona', 'Mississippi', 'New York', 'FL',
#        'AZ', 'DE', 'Nebraska', 'Colorado', 'Minnesota', 'Maine', 'Oregon',
#        'South Dakota', 'South Carolina', 'Wisconsin', 'Montana',
#        'Indiana', 'Oklahoma', 'New Mexico', 'Idaho', 'Souderton',
#        'West Virginia', 'Nevada', 'Washington D.C.', 'Albuquerque',
#        'Connecticut', 'Arkansas', 'Utah', 'Lancaster', 'Vermont',
#        'San Diego', 'Hawaii', 'Alaska', 'Wyoming', 'Iowa'], dtype=object)

# %%
df['State']=df['State'].replace({'TX':'Texas','CO':'Colorado','MD':'Maryland','NV':'Nevada','CA':'California','PA':'Pennsylvania','WA':'Washington','LA':'Louisiana','VA':'Virginia','AL':'Alabama','GA':'Georgia','FL':'Florida','AZ':'Arizona','DE':'Delaware','NM':'New Mexico'})

# %%
df['State'].value_counts()
# Out:
# California         36
# Florida            26
# Texas              20
# Georgia            16
# Washington         16
# Arizona            12
# New York           11
# North Carolina     11
# Illinois           11
# Alabama            11
# Michigan           10
# Ohio               10
# Virginia            9
# Wisconsin           9
# Pennsylvania        8
# Louisiana           7
# Colorado            7
# Tennessee           7
# Kansas              6
# Nevada              6
# South Carolina      5
# Oklahoma            5
# Kentucky            5
# Missouri            4
# Minnesota           4
# New Jersey          4
# Massachusetts       4
# Mississippi         4
# New Mexico          4
# Oregon              4
# Nebraska            3
# Connecticut         3
# Maryland            2
# Arkansas            2
# Utah                2
# Montana             2
# Iowa                1
# Wyoming             1
# Indiana             1
# Vermont             1
# Souderton           1
# ...

# %%
df['State']= df['State'].replace({"Albuquerque":'New Mexico','Lancaster':'Pennsylvania','San Diego':'California','Souderton':'Pennsylvania'})

# %%
df.isnull().sum()
# Out:
# Location                 8
# State                    1
# Date                     0
# Incident Area           16
# Target                   5
# Summary                  0
# Fatalities               0
# Injured                  0
# Total victims            0
# Policeman Killed         6
# Mental Health Issues     0
# Race                     2
# Gender                   0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Location                0
# State                   0
# Date                    0
# Incident Area           0
# Target                  0
# Summary                 0
# Fatalities              0
# Injured                 0
# Total victims           0
# Policeman Killed        0
# Mental Health Issues    0
# Race                    0
# Gender                  0
# dtype: int64

# %%
df.to_excel("shooting.xls")
